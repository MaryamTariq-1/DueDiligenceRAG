# %%
# Check current file structure
# !ls -la /content/DueDiligenceRAG/content/DueDiligenceRAG/

# Check if vector store was created
# !ls -la /content/DueDiligenceRAG/content/DueDiligenceRAG/vector_store/
# Out:
# total 100
# drwxr-xr-x 9 root root 4096 Oct 23 10:03 .
# drwxr-xr-x 3 root root 4096 Oct 23 10:05 ..
# -rw-r--r-- 1 root root 3436 Oct 23 09:53 aws_setup.py
# -rw-r--r-- 1 root root 2114 Oct 23 09:54 check_keys.py
# -rw-r--r-- 1 root root 3408 Oct 23 09:54 config.py
# drwxr-xr-x 2 root root 4096 Oct 23 09:51 Data
# -rw-r--r-- 1 root root 6009 Oct 23 09:54 document_loader.py
# -rw-r--r-- 1 root root  895 Oct 23 10:01 .env
# -rw-r--r-- 1 root root 5210 Oct 23 09:54 evaluation.py
# drwxr-xr-x 8 root root 4096 Oct 23 09:50 .git
# drwxr-xr-x 3 root root 4096 Oct 23 09:50 .idea
# drwxr-xr-x 4 root root 4096 Oct 23 09:50 interview_dataset
# drwxr-xr-x 2 root root 4096 Oct 23 09:51 .ipynb_checkpoints
# -rw-r--r-- 1 root root 1932 Oct 23 09:55 langfuse_test.py
# -rw-r--r-- 1 root root 3888 Oct 23 09:55 main.py
# drwxr-xr-x 2 root root 4096 Oct 23 09:56 __pycache__
# -rw-r--r-- 1 root root 9346 Oct 23 09:55 rag_pipeline.py
# -rw-r--r-- 1 root root  199 Oct 23 09:50 README.md
# ...

# %%
# Run your updated AWS setup
# %cd /content/DueDiligenceRAG/content/DueDiligenceRAG

# Import and run the AWS setup
from aws_setup import aws_complete_test
aws_complete_test()
# Out:
# /content/DueDiligenceRAG/content/DueDiligenceRAG
# AWS S3 SETUP TEST
# ...
# 1. Testing AWS Credentials...
#    SUCCESS: Connected to AWS
#    Found 1 buckets
# 2. Testing Bucket Access...
#    SUCCESS: Bucket exists
# 3. Uploading Files...
#    UPLOADED: training_set/qna_training_data.csv
#    UPLOADED: test_set/finance.txt
#    UPLOADED: test_set/hr.txt
#    UPLOADED: test_set/engineering.txt
#    UPLOADED: test_set/marketing.txt
#    UPLOADED: test_set/operations.txt
# 4. Verifying S3 Structure...
#    S3 Bucket Contents:
#    - test_set/ (0 bytes)
#    - test_set/engineering.txt (873 bytes)
#    - test_set/finance.txt (790 bytes)
#    - test_set/hr.txt (778 bytes)
#    - test_set/marketing.txt (765 bytes)
#    - test_set/operations.txt (803 bytes)
#    - training_set/qna_training_data.csv (2850 bytes)
#    - training_test/ (0 bytes)
#    - training_test/qna_training_data.csv (2850 bytes)
# 5. Testing File Reading...
#    CAN READ: training_set/qna_training_data.csv (21 lines)
# ...

# %%
# Run Langfuse test from your current directory
# %cd /content/DueDiligenceRAG/content/DueDiligenceRAG

# Import and run Langfuse test
from langfuse_test import test_langfuse_working
test_langfuse_working()
# Out:
# /content/DueDiligenceRAG/content/DueDiligenceRAG
#  WORKING LANGFUSE 3.8.0 TEST
# ...
#  Langfuse client initialized
#  Trace created
#  Generation logged
#  Score added
#  Data flushed to Langfuse
#
#  SUCCESS! Langfuse 3.8.0 integration working!
#  Check your dashboard: https://cloud.langfuse.com
# True

# %%
# !pip install langchain-community google-generativeai cohere

# %%
# %cd /content/DueDiligenceRAG/content/DueDiligenceRAG
from document_loader import main as load_documents
load_documents()
# Out:
# /content/DueDiligenceRAG/content/DueDiligenceRAG
# Starting Document Ingestion Pipeline
# ...
# /content/DueDiligenceRAG/content/DueDiligenceRAG/document_loader.py:16: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   self.embeddings = HuggingFaceEmbeddings(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
# %cd /content/DueDiligenceRAG/content/DueDiligenceRAG
from rag_pipeline import test_rag_pipeline
test_rag_pipeline()
# Out:
# /content/DueDiligenceRAG/content/DueDiligenceRAG
# Testing RAG Pipeline with Available Models
# ...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✓ Vector store loaded from disk
# Question: What is the company's approach to financial planning?
#
# Testing: llama-3.3-70b-versatile
# ----------------------------------------
# Testing factual prompt...
#    Retrieved 4 context chunks
# ...

# %%
# %cd /content/DueDiligenceRAG/content/DueDiligenceRAG
from main import main
main()
